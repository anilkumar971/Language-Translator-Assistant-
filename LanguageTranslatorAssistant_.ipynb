# %% [markdown]
# <a href="https://colab.research.google.com/github/anilkumar971/Language-Translator-Assistant-/blob/main/LanguageTranslatorAssistant_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Language Translator Assistant

# %%
# !pip install -q google-genai python-dotenv

# %%
import os
from google.colab import userdata
from google import genai

# %%
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
def language_translator(user_prompt):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user_prompt
    )
    return response.text

# %%
prompt = "Translate 'Hello, how are you?' into Telugu."

# %%
print(language_translator(prompt))
# Out:
# The most common and polite way to translate "Hello, how are you?" into Telugu is:
#
# **నమస్కారం, మీరు ఎలా ఉన్నారు?**
#
# Here's the breakdown:
#
# *   **నమస్కారం** (Namaskāram): Hello / Greetings
# *   **మీరు** (Mīru): You (polite/plural)
# *   **ఎలా** (Ela): How
# *   **ఉన్నారు** (Unnāru): Are (polite/plural)
#
# **Pronunciation:** Nah-mah-skah-rahm, mee-roo eh-lah oon-nah-roo?
#
# **Informal (to a friend, family member, or someone younger):**
#
# **హలో, నువ్వు ఎలా ఉన్నావు?**
#
# *   **హలో** (Halo): Hello (loanword from English)
# *   **నువ్వు** (Nuvvu): You (informal singular)
# *   **ఎలా** (Ela): How
# *   **ఉన్నావు** (Unnāvu): Are (informal singular)
