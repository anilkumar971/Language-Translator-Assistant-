# %% [markdown]
# <a href="https://colab.research.google.com/github/anilkumar971/Language-Translator-Assistant-/blob/main/question_generator0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os
from google.colab import userdata
from google import genai

# %%
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
def question_generator(user_prompt):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user_prompt
    )
    return response.text

# %%
prompt = """
Generate 5 questions from the following text:

Artificial Intelligence is transforming industries by automating tasks,
improving decision-making, and enabling new technologies.
"""

# %%
print(question_generator(prompt))
# Out:
# Here are 5 questions from the text:
#
# 1.  What is transforming industries?
# 2.  Name three ways Artificial Intelligence is transforming industries.
# 3.  What specific aspect of business does AI help to improve?
# 4.  What does Artificial Intelligence do concerning tasks?
# 5.  What kind of technologies does AI enable?
